# %% [markdown]
# # Demo Ingestion Minilab Big Data
#
# Notebook ini membantu menjalankan ingestion tahap 1 dan mengecek log.

# %%
# !python -m ingestion.main_ingest

# %%
import pandas as pd
pd.read_csv('../logs/ingestion_log.csv')
# Out:
#                            timestamp        dataset_name source_type  rows  \
# 0   2026-03-26T04:08:38.089433+00:00   customers_from_db       rdbms     0
# 1   2026-03-26T04:08:38.188150+00:00  customers_from_csv         csv     3
# 2   2026-03-26T04:08:38.779536+00:00  products_from_xlsx        xlsx     3
# 3   2026-03-26T04:18:04.880011+00:00   customers_from_db       rdbms     4
# 4   2026-03-26T04:18:05.188670+00:00  customers_from_csv         csv     3
# 5   2026-03-26T04:18:05.480875+00:00  products_from_xlsx        xlsx     3
# 6   2026-03-26T04:18:36.463925+00:00   customers_from_db       rdbms     4
# 7   2026-03-26T04:18:36.568273+00:00  customers_from_csv         csv     3
# 8   2026-03-26T04:18:36.848111+00:00  products_from_xlsx        xlsx     3
# 9   2026-03-27T15:12:13.959476+00:00   customers_from_db       rdbms    30
# 10  2026-03-27T15:12:14.050985+00:00      orders_from_db       rdbms    63
# ...
